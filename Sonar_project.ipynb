# %% [markdown]
# Target= To distinguish label(output) =R for rock M for mine
# Encoded below as 1= R ,0= M

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('sonar_csv',usecols=range(0,61),header=None)

# %%
data.columns=["Col"+str(i) for i in range(1, 62)]

# %%
data=pd.DataFrame(data=data)

# %%
data
# Out:
#        Col1    Col2    Col3    Col4    Col5    Col6    Col7    Col8    Col9  \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
data.columns
# Out:
# Index(['Col1', 'Col2', 'Col3', 'Col4', 'Col5', 'Col6', 'Col7', 'Col8', 'Col9',
#        'Col10', 'Col11', 'Col12', 'Col13', 'Col14', 'Col15', 'Col16', 'Col17',
#        'Col18', 'Col19', 'Col20', 'Col21', 'Col22', 'Col23', 'Col24', 'Col25',
#        'Col26', 'Col27', 'Col28', 'Col29', 'Col30', 'Col31', 'Col32', 'Col33',
#        'Col34', 'Col35', 'Col36', 'Col37', 'Col38', 'Col39', 'Col40', 'Col41',
#        'Col42', 'Col43', 'Col44', 'Col45', 'Col46', 'Col47', 'Col48', 'Col49',
#        'Col50', 'Col51', 'Col52', 'Col53', 'Col54', 'Col55', 'Col56', 'Col57',
#        'Col58', 'Col59', 'Col60', 'Col61'],
#       dtype='object')

# %%
#since no information attributes are given we have named col1,2 and so on

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
data['Col61']=le.fit_transform(data['Col61'])
data['Col61']
data
# Out:
#        Col1    Col2    Col3    Col4    Col5    Col6    Col7    Col8    Col9  \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %% [markdown]
# EDA

# %%
import seaborn as sns
sns.countplot(data['Col61'])

# %% [markdown]
# from the above observation it is clear that the classes that 1= rock approximatelt 90 and 0= mine is above 100

# %%
data['Col61'].value_counts()
# Out:
# 0    111
# 1     97
# Name: Col61, dtype: int64

# %%
import matplotlib.pyplot as plt
sns.distplot(data['Col61'])
plt.title("Rock and Mine")
plt.show()

# %%
data.corr()
# Out:
#            Col1      Col2      Col3      Col4      Col5      Col6      Col7  \
# Col1   1.000000  0.735896  0.571537  0.491438  0.344797  0.238921  0.260815
# Col2   0.735896  1.000000  0.779916  0.606684  0.419669  0.332329  0.279040
# Col3   0.571537  0.779916  1.000000  0.781786  0.546141  0.346275  0.190434
# Col4   0.491438  0.606684  0.781786  1.000000  0.726943  0.352805  0.246440
# Col5   0.344797  0.419669  0.546141  0.726943  1.000000  0.597053  0.335422
# ...         ...       ...       ...       ...       ...       ...       ...
# Col57  0.313725  0.280341  0.380819  0.340254  0.219395  0.161333  0.186324
# Col58  0.368132  0.353042  0.334108  0.344865  0.238793  0.203986  0.242646
# Col59  0.357116  0.352200  0.425047  0.420266  0.290982  0.220573  0.183578
# Col60  0.347078  0.358761  0.373948  0.400626  0.253710  0.178158  0.222493
# Col61 -0.271694 -0.231238 -0.192195 -0.250638 -0.222232 -0.132327 -0.114748
#
# ...

# %%
data.corr()

import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
sns.heatmap(data.corr(),annot=True,linewidth=0.5,linecolor="black",fmt='2f')

# %%
data.describe
# Out:
# <bound method NDFrame.describe of        Col1    Col2    Col3    Col4    Col5    Col6    Col7    Col8    Col9  \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
data.dtypes
# Out:
# Col1     float64
# Col2     float64
# Col3     float64
# Col4     float64
# Col5     float64
#           ...
# Col57    float64
# Col58    float64
# Col59    float64
# Col60    float64
# Col61      int32
# Length: 61, dtype: object

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import timeit

# %%
data
# Out:
#        Col1    Col2    Col3    Col4    Col5    Col6    Col7    Col8    Col9  \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
data.plot.box(figsize=(12,7), xticks=[])
plt.title('Boxplots of all frequency bins')
plt.xlabel('Frequency bin')
plt.ylabel('Power spectral density (normalized)')
plt.show()

# %% [markdown]
# from the above observation we can find there are some outliers.

# %%
from sklearn.model_selection import train_test_split
x=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
x
# Out:
#        Col1    Col2    Col3    Col4    Col5    Col6    Col7    Col8    Col9  \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 203    0
# 204    0
# 205    0
# 206    0
# 207    0
# Name: Col61, Length: 208, dtype: int32

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(data))
threshold=3
np.where(z>3)
# Out:
# (array([  2,   2,   2,   2,   2,   3,   3,   5,   5,  19,  19,  20,  21,
#          22,  22,  22,  22,  22,  22,  22,  22,  33,  44,  44,  44,  65,
#          85,  85,  87,  91,  91,  97,  97,  98,  98,  98,  98,  98,  98,
#         101, 101, 105, 111, 111, 111, 112, 127, 127, 127, 129, 129, 129,
#         131, 132, 132, 133, 133, 133, 134, 134, 134, 134, 135, 135, 135,
#         135, 136, 136, 136, 136, 137, 137, 138, 138, 138, 140, 140, 140,
#         140, 140, 141, 141, 142, 142, 142, 143, 143, 143, 144, 145, 145,
#         146, 146, 146, 146, 146, 146, 146, 146, 146, 147, 147, 147, 147,
#         147, 147, 147, 147, 161, 184, 186, 186, 186], dtype=int64),
#  array([ 8,  9, 10, 11, 56, 38, 39, 13, 14,  4,  7,  5, 37, 38, 39, 40, 41,
#         46, 47, 48, 49, 49, 39, 42, 43, 58,  1,  2, 56,  5,  6, 58, 59,  0,
#          1,  2,  3,  4, 59, 12, 57, 55,  2,  3,  4, 57, 13, 54, 57,  0, 12,
#         53,  0,  7,  8,  8,  9, 52,  0,  6,  7,  8,  7,  8, 53, 55,  0,  7,
# ...

# %%
data_new=data[(z<3).all(axis=1)]

# %%
data_new
# Out:
#        Col1    Col2    Col3    Col4    Col5    Col6    Col7    Col8    Col9  \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 6    0.0317  0.0956  0.1321  0.1408  0.1674  0.1710  0.0731  0.1401  0.2083
# 7    0.0519  0.0548  0.0842  0.0319  0.1158  0.0922  0.1027  0.0613  0.1465
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
data.shape
# Out:
# (208, 61)

# %%
percentage_loss=((40)/208)*100
print(percentage_loss)
# Out:
# 19.230769230769234

# %%
Q1=data.quantile(0.25)
Q3=data.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# Col1     0.022200
# Col2     0.031500
# Col3     0.039000
# Col4     0.040125
# Col5     0.062225
#            ...
# Col57    0.006725
# Col58    0.006750
# Col59    0.006650
# Col60    0.005425
# Col61    1.000000
# Length: 61, dtype: float64

# %%
data_new1=data[~((data<Q1-(1.5*IQR))|(data>(Q3+(1.5*IQR)))).any(axis=1)]

# %%
print(data_new1.shape)
# Out:
# (134, 61)

# %%
percentage_loss=((74)/208)*100
print(percentage_loss)
# Out:
# 35.57692307692308

# %% [markdown]
# From the available 2 methods of outliers removing technique we can conclude z SCORE is the most feasable to adaopt as 19% of data is lost compared to quantilte method where we will loose 35% od data approximately

# %%
from sklearn.model_selection import train_test_split
x=data_new.iloc[:,:-1]
y=data_new.iloc[:,-1]

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %% [markdown]
# Regressor model

# %%
x.shape
# Out:
# (168, 60)

# %%
y.shape
# Out:
# (168,)

# %%
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
pca=PCA(n_components=10)

# %%
x=pca.fit_transform(x)

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()

# %%
x=scale.fit_transform(x)

# %%
y=le.fit_transform(y)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=45)

# %% [markdown]
# Classification

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
predlr=lr.predict(x_test)
print(accuracy_score(y_test,predlr))
print(confusion_matrix(y_test,predlr))
print(classification_report(y_test,predlr))
# Out:
# 0.7837837837837838
# [[16  5]
#  [ 3 13]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.76      0.80        21
#            1       0.72      0.81      0.76        16
#
#     accuracy                           0.78        37
#    macro avg       0.78      0.79      0.78        37
# weighted avg       0.79      0.78      0.78        37

# %%
gnb=GaussianNB()

# %%
gnb.fit(x_train,y_train)
gnb.score(x_train,y_train)
predgnb=gnb.predict(x_test)
print(accuracy_score(y_test,predgnb))
print(confusion_matrix(y_test,predgnb))
print(classification_report(y_test,predgnb))
# Out:
# 0.8648648648648649
# [[19  2]
#  [ 3 13]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88        21
#            1       0.87      0.81      0.84        16
#
#     accuracy                           0.86        37
#    macro avg       0.87      0.86      0.86        37
# weighted avg       0.86      0.86      0.86        37

# %%
svc=SVC()

# %%
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.8648648648648649
# [[18  3]
#  [ 2 14]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88        21
#            1       0.82      0.88      0.85        16
#
#     accuracy                           0.86        37
#    macro avg       0.86      0.87      0.86        37
# weighted avg       0.87      0.86      0.87        37

# %%
svc=SVC(kernel='poly')
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.7297297297297297
# [[12  9]
#  [ 1 15]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.57      0.71        21
#            1       0.62      0.94      0.75        16
#
#     accuracy                           0.73        37
#    macro avg       0.77      0.75      0.73        37
# weighted avg       0.79      0.73      0.72        37

# %%
svc=SVC(kernel='rbf')
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.8648648648648649
# [[18  3]
#  [ 2 14]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88        21
#            1       0.82      0.88      0.85        16
#
#     accuracy                           0.86        37
#    macro avg       0.86      0.87      0.86        37
# weighted avg       0.87      0.86      0.87        37

# %%
svc=SVC(kernel='poly')
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.7297297297297297
# [[12  9]
#  [ 1 15]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.57      0.71        21
#            1       0.62      0.94      0.75        16
#
#     accuracy                           0.73        37
#    macro avg       0.77      0.75      0.73        37
# weighted avg       0.79      0.73      0.72        37

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
dt.score(x_train,y_train)
preddt=dt.predict(x_test)
print(accuracy_score(y_test,preddt))
print(confusion_matrix(y_test,preddt))
print(classification_report(y_test,preddt))
# Out:
# 0.8648648648648649
# [[17  4]
#  [ 1 15]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87        21
#            1       0.79      0.94      0.86        16
#
#     accuracy                           0.86        37
#    macro avg       0.87      0.87      0.86        37
# weighted avg       0.88      0.86      0.87        37

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()

# %%
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
preddt=knn.predict(x_test)
print(accuracy_score(y_test,preddt))
print(confusion_matrix(y_test,preddt))
print(classification_report(y_test,preddt))
# Out:
# 0.918918918918919
# [[18  3]
#  [ 0 16]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92        21
#            1       0.84      1.00      0.91        16
#
#     accuracy                           0.92        37
#    macro avg       0.92      0.93      0.92        37
# weighted avg       0.93      0.92      0.92        37

# %% [markdown]
# Classification type	    Accuracy
# LogisticRegression	    0.783783784
# GaussianNB         	    0.864864865
# SVC(kernel='poly')  	0.72972973
# SVC             	    0.864864865
# SVC(kernel='rbf')   	0.864864865
# DecisionTreeClassifier	0.783783784
# KNeighborsClassifier	0.918918919

# %% [markdown]
# fromthe aboove classification analysis it is evident that KNeighborsClassifier is the best fit for sonar dataset

# %% [markdown]
# Regularization

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import r2_score

# %%
max_scr=0
for i in range (0,500):
    x_train,x_test,y_train,y_test=train_test_split(x_t,y,random_state=i,test_size=.20) 
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(r2_score(y_train,pred_train)*100,2)==round(r2_score(y_test,pred_test)*100,2):
        print("At random state:- ",i,"The model performs very well")
        print("At random_state:-",i)
        print("Training r2_score is :-",r2_score(y_train,pred_train)*100)
        print("tESTING R2_SCORE IS :-",r2_score(y_test,pred_test)*100)

# %%
x_train,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-127-96b9fcea854d> in <module>
# ----> 1 x_train,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.20)
#
# ValueError: too many values to unpack (expected 3)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Lasso:

# %%
from sklearn.linear_model import Lasso

parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf= GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.01, 'random_state': 0}

# %%
ls=Lasso(alpha=0.1,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)

lss=r2_score(y_test,pred_ls)
for j in range (10,100):
    lsscore=cross_val_score(ls,x,y,cv=j)
    lsc=lsscore.mean()
    print("At cv:-",j)
    print("Cross validation score is :-",lsc*100)
    print("R2_score is:-",lss*100)
    print("\n")
# Out:
# At cv:- 10
# Cross validation score is :- -50.83400273005132
# R2_score is:- 25.100296603770012
#
#
# At cv:- 11
# Cross validation score is :- -9.636527500099081
# R2_score is:- 25.100296603770012
#
#
# At cv:- 12
# Cross validation score is :- 0.0
# R2_score is:- 25.100296603770012
#
#
# At cv:- 13
# Cross validation score is :- -5.748851403499254
# R2_score is:- 25.100296603770012
#
#
# At cv:- 14
# Cross validation score is :- 0.0
# R2_score is:- 25.100296603770012
#
#
# At cv:- 15
# Cross validation score is :- -7.3080911894338865
# R2_score is:- 25.100296603770012
#
#
# At cv:- 16
# Cross validation score is :- -2.0690295301463517
# R2_score is:- 25.100296603770012
#
#
# At cv:- 17
# Cross validation score is :- -5.030158290410622
# R2_score is:- 25.100296603770012
#
#
# At cv:- 18
# Cross validation score is :- -0.7591368817560383
# R2_score is:- 25.100296603770012
#
#
# At cv:- 19
# Cross validation score is :- -6.049615356470742
# R2_score is:- 25.100296603770012
#
#
# ...

# %%
ls=Lasso(alpha=0.1,random_state=0)
ls.fit(x_train_b,y_train_b)
ls.score(x_train_b,y_train_b)
pred_ls=ls.predict(x_test_b)
lss=r2_score(y_test_b,pred_ls)
for j in range(2,10):
    lssscore=cross_val_score(ls,x_t,u,cv=j)
    lsc=lsscore.mean()
    print("At cv:-",j")
          print("Crossvalidation score is:-",lsc*100)
          print("R2_score is:-",lss*100)
          print("\n")

# %%
print ("at cv :-",12)
print("at cross validation score is :-",0.0)
print("r2_score:-",25.100296)
# Out:
# at cv :- 12
# at cross validation score is :- 0.0
# r2_score:- 25.100296

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
print('Error:-')
print('MeanAbsoluteError:',mean_absolute_error(y_test,pred_ls))
print('MeanSquaredError:',mean_squared_error(y_test,pred_ls))
print('RootMeanSquareError:',np.sqrt(mean_squared_error(y_test,pred_ls)))
# Out:
# Error:-
# MeanAbsoluteError: 0.41181087499007724
# MeanSquaredError: 0.18141796670367127
# RootMeanSquareError: 0.42593188035608615

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_ls,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel("Actual Rock and Mine",fontsize=14)
plt.ylabel("Predicted Rock and Mine",fontsize=14)
plt.title("LassoRegression",fontsize=18)
plt.show()

# %% [markdown]
# Ridge Regression

# %%
from sklearn.linear_model import Ridge

parameters={'alpha': [.0001,.001,.01,.1,1],'fit_intercept':[True,False],'copy_x':[True,False],'tol':[.0001,.001,.01,.1,1]}
rd=Ridge()
clf=GridSearchCV(rd,parameters)
clf.fit(x_train,y_train)
           
print(clf.best_params_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-147-9ac44a34b7fc> in <module>
#       4 rd=Ridge()
#       5 clf=GridSearchCV(rd,parameters)
# ----> 6 clf.fit(x_train,y_train)
#       7
#       8 print(clf.best_params_)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ...

# %%
from sklearn.tree import DecisionTreeRegressor

parameters={'criterion':['mse','friedman_mse','mac'],'splitter':['best','random']}
dt=DecisionTreeRegressor()
clf=GridSearchCV(dt,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'friedman_mse', 'splitter': 'best'}

# %%
dt=DecisionTreeRegressor(criterion='friedman_mse',splitter='best')
dt.fit(x_train,y_train)
dt.score(x_train,y_train)
pred_decision=dt.predict(x_test)

dts=r2_score(y_test,pred_decision)
print('R2 Score:',dts*100)

dtscore=cross_val_score(dt,x,y,cv=12)
dtc=dtscore.mean()
print('cross val score:',dtc*100)
# Out:
# R2 Score: 15.000000000000014
# cross val score: 8.333333333333332

# %%
print('Error:-')
print('MeanAbsoluteError:',mean_absolute_error(y_test,pred_decision))
print('MeanSquaredError:',mean_squared_error(y_test,pred_decision))
print('RootMeanSquareError:',np.sqrt(mean_squared_error(y_test,pred_decision)))
# Out:
# Error:-
# MeanAbsoluteError: 0.20588235294117646
# MeanSquaredError: 0.20588235294117646
# RootMeanSquareError: 0.45374260648651504

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_decision,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel("Actual Rock and Mine",fontsize=14)
plt.ylabel("Predicted Rock and Mine",fontsize=14)
plt.title("DecisionTreeRegressor",fontsize=18)
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

parameters={'criterion':['friedman_mse','mae'],'n_estimators':[100,200,300]}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
                         
print(clf.best_params_)
# Out:
# {'criterion': 'friedman_mse', 'n_estimators': 100}

# %%
rf=RandomForestRegressor(criterion='friedman_mse',n_estimators=100)
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_random=rf.predict(x_test)

rfs=r2_score(y_test,pred_random)
print('R2 Score:',rfs*100)

rfscore=cross_val_score(rf,x,y,cv=12)
rfc=rfscore.mean()
print('cross val score:',rfc*100)
# Out:
# R2 Score: 52.86142857142857
# cross val score: 0.0

# %%
print('Error:-')
print('MeanAbsoluteError:',mean_absolute_error(y_test,pred_random))
print('MeanSquaredError:',mean_squared_error(y_test,pred_random))
print('RootMeanSquareError:',np.sqrt(mean_squared_error(y_test,pred_random)))
# Out:
# Error:-
# MeanAbsoluteError: 0.25470588235294117
# MeanSquaredError: 0.1141764705882353
# RootMeanSquareError: 0.33790008965407997

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_random,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel("Actual Rock and Mine",fontsize=14)
plt.ylabel("Predicted Rock and Mine",fontsize=14)
plt.title("RandomForestRegressor",fontsize=18)
plt.show()

# %%
from sklearn.datasets import make_regression
from sklearn.ensemble import GradientBoostingRegressor
parameters={'loss':['ls','lad','huber','quantile'],'n_estimators':[50,100,200],'criterion':['friedman_mse','mse']}
gbr=GradientBoostingRegressor()
clf=GridSearchCV(gbr,parameters)
clf.fit(x_train,y_train)
                         
print(clf.best_params_)
# Out:
# {'criterion': 'friedman_mse', 'loss': 'ls', 'n_estimators': 50}

# %%
gbr=GradientBoostingRegressor(criterion='friedman_mse',loss='ls',n_estimators=50)
gbr.fit(x_train,y_train)
gbr.score(x_train,y_train)
pred_gbr=gbr.predict(x_test)

gbrs=r2_score(y_test,pred_random)
print('R2 SCORE',gbrs*100)

gbscore=cross_val_score(gbr,x,y,cv=12)
gbrc=gbscore.mean()
print('CrossValScore:',gbrc*100)
# Out:
# R2 SCORE 52.86142857142857
# CrossValScore: 0.0

# %%
print('Error:-')
print('MeanAbsoluteError:',mean_absolute_error(y_test,pred_gbr))
print('MeanSquaredError:',mean_squared_error(y_test,pred_gbr))
print('RootMeanSquareError:',np.sqrt(mean_squared_error(y_test,pred_gbr)))
# Out:
# Error:-
# MeanAbsoluteError: 0.2403334200585155
# MeanSquaredError: 0.11660327348676496
# RootMeanSquareError: 0.34147221480929446

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_gbr,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel("Actual Rock and Mine",fontsize=14)
plt.ylabel("Predicted Rock and Mine",fontsize=14)
plt.title("GradientBoostingRegressor",fontsize=18)
plt.show()

# %%
from sklearn.svm import SVR

parameters={'kernel':['linear','poly','rbf','sigmoid'],'gama':['auto','scale']}
sv=SVR()
clf=GridSearchCV(sv,parameters)
clf.fit(x_train,y_train)

print('clf.best_params_')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-183-953161ccaa0e> in <module>
#       4 sv=SVR()
#       5 clf=GridSearchCV(sv,parameters)
# ----> 6 clf.fit(x_train,y_train)
#       7
#       8 print('clf.best_params_')
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ...

# %%
#The best model accordint cross validation and r2 score is random forest

# %%
import pickle
filename='Sonar project.pkl'
pickle.dump(gbr,open(filename,'wb'))

# %% [markdown]
# CONCLUSION

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(gbr.predict(x_test))

# %%
df=pd.DataFrame({"original":a,"predict":predicted},index=range(len(a)))

# %%
df
# Out:
#     original   predict
# 0          0  0.167769
# 1          0  0.003736
# 2          0  0.147603
# 3          0  0.123539
# 4          1  0.423314
# 5          0  0.854317
# 6          1  0.902056
# 7          0  0.214134
# 8          1  0.726027
# 9          0  0.157003
# 10         1  0.902215
# 11         1  0.799119
# 12         1  1.011065
# 13         1  1.134298
# 14         0 -0.004412
# 15         0  0.089669
# 16         0  0.482492
# 17         1  1.090927
# 18         1  0.786010
# 19         0  0.206366
# 20         0 -0.005009
# 21         0  0.069735
# 22         0  0.239279
# 23         1  0.340929
# 24         1  0.515027
# 25         0  0.235911
# 26         0  0.998409
# 27         1  0.829747
# 28         0  0.326625
# 29         0  0.046973
# 30         1  0.894679
# 31         0  0.068689
# 32         0  0.031765
# 33         1  0.419263

# %%
#from the above table the modelis predicted with 52% accuracy
